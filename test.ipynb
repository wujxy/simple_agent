# %%
from simple_agent.agent import SimpleAgent
import os

os.environ['ZHIPU_API_KEY'] = '6c33937d2e5d461297fa7d0736fff6ec.dZfTpqiXX7xDR65G'

agent = SimpleAgent.from_config("configs")
result = agent.run("Read README.md and summarize the project")
print(result)
# Out:
# [INFO] agent: Starting task: Read README.md and summarize the project
# [INFO] agent: Plan generated: 3 steps
# [INFO] agent: Step 1: read_file({'path': 'README.md'}) -> # simple_agent
#
# A clean, minimal AI agent framework in Python. Built on a structured plan → act → ob
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 os.environ['ZHIPU_API_KEY'] = '6c33937d2e5d461297fa7d0736fff6ec.dZfTpqiXX7xDR65G'
#       6 agent = SimpleAgent.from_config("configs")
# ----> 7 result = agent.run("Read README.md and summarize the project")
#       8 print(result)
#
# File ~/Agents/my_agent/simple_agent/simple_agent/agent.py:203, in SimpleAgent.run(self, task)
#     201 # --- Summary ---
#     202 summary_prompt = build_summary_prompt(task, actions_summary)
# --> 203 summary_output = self._llm.generate(summary_prompt)
# ...
